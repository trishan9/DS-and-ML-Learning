# %% [markdown]
# # Naive Bayes Classifiers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ## **Gaussian Naive Bayes**

# %% [markdown]
# ### Import Data

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %% [markdown]
# ### Model Training

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

gnb = make_pipeline(StandardScaler(), GaussianNB())
gnb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gaussiannb', GaussianNB())])

# %% [markdown]
# ### Model Results & Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = gnb.predict(X_test)
print("GaussianNB Accuracy:", accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['setosa', 'versicolor', 'virginica'], 
                yticklabels=['setosa', 'versicolor', 'virginica'])
plt.title("Confusion Matrix for GaussianNB")
plt.show()
# Out:
# GaussianNB Accuracy: 0.9666666666666667

# %%
print("Classification Report for GaussianNB: \n", classification_report(y_test, y_pred))
# Out:
# Classification Report for GaussianNB:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      0.89      0.94         9
#            2       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ---

# %% [markdown]
# ## **Multinomial Naive Bayes**

# %% [markdown]
# ### Import Data

# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups = fetch_20newsgroups(subset='all', categories=['sci.crypt', 'talk.politics.misc'])
X = newsgroups.data
y = newsgroups.target

# %% [markdown]
# ### Data Preprocessing (Text data to word count vectors)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X_counts = vectorizer.fit_transform(X)

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_counts, y, test_size=0.2, random_state=12)

# %% [markdown]
# ### Model Training

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

mnb = make_pipeline(MultinomialNB())
mnb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('multinomialnb', MultinomialNB())])

# %% [markdown]
# ### Model Results & Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = mnb.predict(X_test)
print("MultinomialNB Accuracy:", accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['crypt', 'politics'], 
                yticklabels=['crypt', 'politics'])
plt.title("Confusion Matrix for MultinomialNB")
plt.show()
# Out:
# MultinomialNB Accuracy: 0.9774011299435028

# %%
print("Classification Report for MultinomialNB: \n", classification_report(y_test, y_pred))
# Out:
# Classification Report for MultinomialNB:
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       188
#            1       0.99      0.96      0.98       166
#
#     accuracy                           0.98       354
#    macro avg       0.98      0.98      0.98       354
# weighted avg       0.98      0.98      0.98       354

# %% [markdown]
# ---

# %% [markdown]
# ## **Bernoulli Naive Bayes**

# %% [markdown]
# ### Import Data

# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups = fetch_20newsgroups(subset='all', categories=['sci.crypt', 'talk.politics.misc'])

# %% [markdown]
# ### Data Preprocessing (Text data to binary features)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(binary=True)
X = vectorizer.fit_transform(newsgroups.data)
y = newsgroups.target

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %% [markdown]
# ### Model Training

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.pipeline import make_pipeline

bnb = make_pipeline(BernoulliNB())
bnb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('bernoullinb', BernoulliNB())])

# %% [markdown]
# ### Model Results & Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = bnb.predict(X_test)
print("BernoulliNB Accuracy:", accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['crypt', 'politics'], 
                yticklabels=['crypt', 'politics'])
plt.title("Confusion Matrix for BernoulliNB")
plt.show()
# Out:
# BernoulliNB Accuracy: 0.9519774011299436

# %%
print("Classification Report for BernoulliNB: \n", classification_report(y_test, y_pred))
# Out:
# Classification Report for BernoulliNB:
#                precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       188
#            1       0.98      0.92      0.95       166
#
#     accuracy                           0.95       354
#    macro avg       0.96      0.95      0.95       354
# weighted avg       0.95      0.95      0.95       354
